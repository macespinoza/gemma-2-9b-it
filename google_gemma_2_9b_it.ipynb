# %%
from IPython.display import clear_output

# %%
# !pip install -U accelerate bitsandbytes transformers huggingface_hub
clear_output()

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# The token `gemma2` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `gemma2`

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(load_in_8bit=True)

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-9b-it")

model = AutoModelForCausalLM.from_pretrained("google/gemma-2-9b-it", quantization_config=quantization_config)
# Out:
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/857 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/39.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]

# %%
#entra de texto
input_text = "indicame las caracteristicas de python en formato de lista ordenado del mayor beneficio al menor"

#return_tensors "pt" para convertir en pytorch que es lo que acepta modelo
#cuda mueve el tensor a la GPU
input_ds = tokenizer(input_text, return_tensors="pt").to("cuda")

#limitar la generacion del toke
output = model.generate(**input_ds, max_new_tokens=1024)
#decodifica los tokens generados a un medio legible
print(tokenizer.decode(output[0]))
# Out:
# <bos>indicame las caracteristicas de python en formato de lista ordenado del mayor beneficio al menor.
#
# ## Características de Python (Ordenadas por Beneficio)
#
# **Alto Nivel:**
#
# 1. **Sintaxis clara y legible:** Python se enfoca en la legibilidad del código, haciendo que sea fácil de entender y mantener, incluso para principiantes.
#
# 2. **Interpretado:** No requiere compilación previa, lo que permite un desarrollo más rápido y flexible.
#
# **Versatilidad:**
#
# 3. **Amplia biblioteca estándar:** Ofrece una gran cantidad de módulos y funciones predefinidas para diversas tareas, desde manejo de archivos hasta análisis de datos.
#
# 4. **Ecosystem robusto:** Cuenta con una comunidad activa y un vasto repositorio de paquetes (pip) que amplían sus capacidades en áreas como aprendizaje automático, desarrollo web y ciencia de datos.
#
# **Facilidad de Aprendizaje:**
#
# 5. **Sintaxis simple y concisa:** Python utiliza una sintaxis similar al inglés, lo que facilita su aprendizaje y comprensión.
#
# 6. **Recursos abundantes:** Existe una gran cantidad de tutoriales, cursos y documentación disponible en línea y en formato impreso.
#
# **Otras Características:**
#
# 7. **Multiplataforma:** Python funciona en diferentes sistemas operativos como Windows, macOS y Linux.
#
# 8. **Orientado a objetos:** Permite la creación de programas modularizados y reutilizables.
#
# 9. **Soporte para programación asíncrona:** Facilita el desarrollo de aplicaciones que manejan múltiples tareas simultáneamente.
#
# **Nota:** El orden de las características puede variar según las necesidades y preferencias del usuario.
#
#
# <end_of_turn><eos>
